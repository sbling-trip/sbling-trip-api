# %%
import pandas as pd
import sqlalchemy

# %%
df = pd.read_csv("result.csv", index_col=0)
df
# Out:
#                    stay_name   manager                contact_number  \
# 0                     카이 호스텔       NaN                  064-796-2428
# 1                   돈내코힐 리조트       오순제                 010-7277-1439
# 2                      바다해호텔       최성환                  064-762-5530
# 3    먼나머루휴양펜션(제주편백한옥펜션 먼나머루)       NaN                 010-9300-3363
# 4                    쉴띠 휴양펜션  신동심, 오수진  010-3697-6695, 010-4692-1104
# ..                       ...       ...                           ...
# 210                  제주 써니데이       NaN                 010-3808-5204
# 211                 제주 지삿개풍경       NaN                  064-738-5353
# 212                 까델아스 리조트       NaN                  064-799-7996
# 213                    늘송파크텔       박노환                 010-9264-4831
# 214                  제주 추억여행       NaN                  064-739-7999
#
#                         address check_in_time check_in_additonal_info  \
# ...

# %%
from sqlalchemy import create_engine
# Replace the following with your own details
username = 'postgres'
password = 'sibling'
host = 'localhost'
port = '5432'
database = 'postgres'

# Create the engine
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')

# %%
from sqlalchemy import URL, create_engine

connection_string = URL.create(
    'postgresql',
    username='koyeb-adm',
    password='DJHUfAp4GRz1',
    host='ep-blue-smoke-85382464.us-east-1.aws.neon.tech',
    database='koyebdb',
)

engine = create_engine(connection_string)

# %%
engine
# Out:
# Engine(postgresql://koyeb-adm:***@ep-blue-smoke-85382464.us-east-1.aws.neon.tech/koyebdb)

# %%
df["check_in_time"]
# Out:
# 0      15:00
# 1      15:00
# 2      16:00
# 3      13:00
# 4      16:00
#        ...
# 210    14:00
# 211    14:00
# 212    15:00
# 213    14:00
# 214    15:00
# Name: check_in_time, Length: 215, dtype: object

# %%
def standardize_time(time_str):
    if pd.isna(time_str):
        return None
    if '시' in time_str:
        return time_str.replace('시', ':00')
    return time_str

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 50000)

# %%
df["check_in_time"] = df["check_in_time"].apply(standardize_time)
df["check_out_time"] = df["check_out_time"].apply(standardize_time)
df[["check_in_time", "check_out_time"]]
# Out:
#     check_in_time check_out_time
# 0           15:00          11:30
# 1           15:00          11:00
# 2           16:00          11:00
# 3           13:00          12:00
# 4           16:00          11:00
# 5           15:00          12:00
# 6           15:00          11:00
# 7           16:00          11:00
# 8           15:00          11:00
# 9           14:00          12:00
# 10          15:00          11:00
# 11          15:00          12:00
# 12          16:00          11:00
# 13          15:00          11:00
# 14          15:00          11:00
# 15          14:00          11:00
# 16          15:00          11:00
# 17          17:00          11:00
# 18          15:00          12:00
# 19          15:00          11:00
# 20          15:00          11:00
# 21          15:00          11:00
# 22          15:00          12:00
# 23          15:00          12:00
# 24          15:00          11:00
# 25          14:00          11:00
# 26          15:00          11:00
# ...

# %%
df.to_sql("stay_info", engine, if_exists="append", index=False)
# Out:
# 215
